# %% [markdown]
# # Checkpoint 1

# %% [markdown]
# Reminder:
#
# - You are being evaluated for compeletion and effort in this checkpoint.
# - Avoid manual labor / hard coding as much as possible, everything we've taught you so far are meant to simplify and automate your process.

# %% [markdown]
# We will be working with the same `states_edu.csv` that you should already be familiar with from the tutorial.
#
# We investigated Grade 8 reading score in the tutorial. For this checkpoint, you are asked to investigate another test. Here's an overview:
#
# * Choose a specific response variable to focus on
# >Grade 4 Math, Grade 4 Reading, Grade 8 Math
# * Pick or create features to use
# >Will all the features be useful in predicting test score? Are some more important than others? Should you standardize, bin, or scale the data?
# * Explore the data as it relates to that test
# >Create at least 2 visualizations (graphs), each with a caption describing the graph and what it tells us about the data
# * Create training and testing data
# >Do you want to train on all the data? Only data from the last 10 years? Only Michigan data?
# * Train a ML model to predict outcome
# >Define what you want to predict, and pick a model in sklearn to use (see sklearn <a href="https://scikit-learn.org/stable/modules/linear_model.html">regressors</a>.
# * Summarize your findings
# >Write a 1 paragraph summary of what you did and make a recommendation about if and how student performance can be predicted
#
# Include comments throughout your code! Every cleanup and preprocessing task should be documented.
#
# Of course, if you're finding this assignment interesting (and we really hope you do!), you are welcome to do more than the requirements! For example, you may want to see if expenditure affects 4th graders more than 8th graders. Maybe you want to look into the extended version of this dataset and see how factors like sex and race are involved. You can include all your work in this notebook when you turn it in -- just always make sure you explain what you did and interpret your results. Good luck!

# %% [markdown]
# <h2> Data Cleanup </h2>
#
# Import `numpy`, `pandas`, and `matplotlib`.
#
# (Feel free to import other libraries!)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load in the "states_edu.csv" dataset and take a look at the head of the data

# %%
df = pd.read_csv('../data/states_edu.csv')
df.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992     NaN      2678885.0         304177.0
# 1      1992_ALASKA      ALASKA  1992     NaN      1049591.0         106780.0
# 2     1992_ARIZONA     ARIZONA  1992     NaN      3258079.0         297888.0
# 3    1992_ARKANSAS    ARKANSAS  1992     NaN      1711959.0         178571.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0      1659028.0       715680.0          2653798.0                1481703.0
# 1       720711.0       222100.0           972488.0                 498362.0
# 2      1369815.0      1590376.0          3401580.0                1435908.0
# 3       958785.0       574603.0          1743022.0                 964323.0
# 4     16546514.0      7641041.0         27138832.0               14358922.0
#
# ...

# %% [markdown]
# You should always familiarize yourself with what each column in the dataframe represents. Read about the states_edu dataset here: https://www.kaggle.com/noriuk/us-education-datasets-unification-project

# %% [markdown]
# Use this space to rename columns, deal with missing data, etc. _(optional)_

# %%
df.rename({
    'GRADES_PK_G':'ENROLL_PREK',
    'GRADES_KG_G':'ENROLL_KINDER',
    'GRADES_4_G':'ENROLL_4',
    'GRADES_8_G':'ENROLL_8',
    'GRADES_12_G':'ENROLL_12',
    'GRADES_1_8_G':'ENROLL_PRIMARY',
    'GRADES_9_12_G':'ENROLL_HS',
    'GRADES_ALL_G':'ENROLL_ALL',
    'ENROLL':'ENROLL_ALL_EST'
    },
    axis=1,inplace=True)
df.columns
# Out:
# Index(['PRIMARY_KEY', 'STATE', 'YEAR', 'ENROLL_ALL_EST', 'TOTAL_REVENUE',
#        'FEDERAL_REVENUE', 'STATE_REVENUE', 'LOCAL_REVENUE',
#        'TOTAL_EXPENDITURE', 'INSTRUCTION_EXPENDITURE',
#        'SUPPORT_SERVICES_EXPENDITURE', 'OTHER_EXPENDITURE',
#        'CAPITAL_OUTLAY_EXPENDITURE', 'ENROLL_PREK', 'ENROLL_KINDER',
#        'ENROLL_4', 'ENROLL_8', 'ENROLL_12', 'ENROLL_PRIMARY', 'ENROLL_HS',
#        'ENROLL_ALL', 'AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE',
#        'AVG_READING_4_SCORE', 'AVG_READING_8_SCORE'],
#       dtype='object')

# %% [markdown]
# <h2>Exploratory Data Analysis (EDA) </h2>

# %% [markdown]
# Chosen Outcome Variable for Test: *['STATE','AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE','AVG_READING_4_SCORE', 'AVG_READING_8_SCORE']*

# %% [markdown]
# How many years of data are logged in our dataset?

# %%
df = pd.read_csv('../data/states_edu.csv')
print(len(df.groupby('YEAR')))
print(df["YEAR"].nunique())
# Out:
# 33
# 33

# %% [markdown]
# Let's compare Michigan to Ohio. Which state has the higher average outcome score across all years?

# %%
AVE_SCORE_MICHIGAN_OHIO = df.loc[(df["STATE"] == "MICHIGAN") | (df["STATE"] == "OHIO"), 
                                ['STATE','AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE','AVG_READING_4_SCORE', 'AVG_READING_8_SCORE']]
AVE_SCORE_MICHIGAN_OHIO = AVE_SCORE_MICHIGAN_OHIO.dropna()
AVE_SCORE_MICHIGAN_OHIO.head()

AVE_SCORE_MICHIGAN_OHIO.groupby("STATE")[['AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE','AVG_READING_4_SCORE', 'AVG_READING_8_SCORE']].mean()
#Ohio has higher average outcome score for all four scores
# Out:
#           AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  AVG_READING_4_SCORE  \
# STATE
# MICHIGAN        236.555556        278.444444           218.111111
# OHIO            242.777778        286.000000           224.000000
#
#           AVG_READING_8_SCORE
# STATE
# MICHIGAN           263.333333
# OHIO               267.666667

# %% [markdown]
# Find the average for your outcome score across all states in 2019

# %%
data_2019 = df.loc[df["YEAR"] == '2019', 
                    ['STATE','AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE','AVG_READING_4_SCORE', 'AVG_READING_8_SCORE']]
# df.dtypes
#the above assignment create unexpected data frame because I assume data type of column 'YEAR' is string
data_2019 = df.loc[df["YEAR"] == 2019, 
                    ['STATE','AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE','AVG_READING_4_SCORE', 'AVG_READING_8_SCORE']]
data_2019.groupby("STATE").mean()
# Out:
#                       AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  AVG_READING_4_SCORE  \
# STATE
# ALABAMA                          230.0             269.0                212.0
# ALASKA                           232.0             274.0                204.0
# ARIZONA                          238.0             280.0                216.0
# ARKANSAS                         233.0             274.0                215.0
# CALIFORNIA                       235.0             276.0                216.0
# COLORADO                         242.0             285.0                225.0
# CONNECTICUT                      243.0             286.0                224.0
# DELAWARE                         239.0             277.0                218.0
# DISTRICT_OF_COLUMBIA             235.0             269.0                214.0
# DODEA                            250.0             292.0                235.0
# FLORIDA                          246.0             279.0                225.0
# ...

# %% [markdown]
# Find the maximum outcome score for every state.
#
# Refer to the `Grouping and Aggregating` section in Tutorial 0 if you are stuck.

# %%
sort_by_state = df.groupby("STATE")
sort_by_state[['AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE','AVG_READING_4_SCORE', 'AVG_READING_8_SCORE']].max()
# Out:
#                       AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  AVG_READING_4_SCORE  \
# STATE
# ALABAMA                          233.0             269.0                220.0
# ALASKA                           237.0             283.0                214.0
# ARIZONA                          240.0             283.0                216.0
# ARKANSAS                         240.0             279.0                219.0
# CALIFORNIA                       235.0             277.0                216.0
# COLORADO                         247.0             292.0                227.0
# CONNECTICUT                      245.0             289.0                230.0
# DELAWARE                         243.0             284.0                226.0
# DISTRICT_OF_COLUMBIA             235.0             269.0                214.0
# DODEA                            250.0             293.0                235.0
# FLORIDA                          246.0             281.0                228.0
# ...

# %% [markdown]
# <h2> Feature Engineering </h2>
#
# After exploring the data, you can choose to modify features that you would use to predict the performance of the students on your chosen response variable.
#
# You can also create your own features. For example, perhaps you figured that maybe a state's expenditure per student may affect their overall academic performance so you create a expenditure_per_student feature.
#
# Use this space to modify or create features.

# %%
# In this project, we set 'AVG_MATH_8_SCORE' as response variable. 
# 'AVG_MATH_4_SCORE', 'AVG_READING_4_SCORE', 'AVG_READING_8_SCORE' are input variables

df = df.loc[::, ['AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE',
       'AVG_READING_4_SCORE', 'AVG_READING_8_SCORE']]

# %% [markdown]
# Feature engineering justification: **<After finding the strong correlation between AVG_MATH_8_SCORE and other three test scores, I plan to use least squares linear regression to predict AVG_MATH_8_SCORE based on other three test scores. To do this, I cleaned the data, dropping rows that have NA in input variables and filling NA in output variable with median of output values in this dataset\>**

# %% [markdown]
# <h2>Visualization</h2>
#
# Investigate the relationship between your chosen response variable and at least two predictors using visualizations. Write down your observations.
#
# **Visualization 1**

# %%
pd.plotting.scatter_matrix(df, figsize = (15,15))
# Out:
# array([[<Axes: xlabel='AVG_MATH_4_SCORE', ylabel='AVG_MATH_4_SCORE'>,
#         <Axes: xlabel='AVG_MATH_8_SCORE', ylabel='AVG_MATH_4_SCORE'>,
#         <Axes: xlabel='AVG_READING_4_SCORE', ylabel='AVG_MATH_4_SCORE'>,
#         <Axes: xlabel='AVG_READING_8_SCORE', ylabel='AVG_MATH_4_SCORE'>],
#        [<Axes: xlabel='AVG_MATH_4_SCORE', ylabel='AVG_MATH_8_SCORE'>,
#         <Axes: xlabel='AVG_MATH_8_SCORE', ylabel='AVG_MATH_8_SCORE'>,
#         <Axes: xlabel='AVG_READING_4_SCORE', ylabel='AVG_MATH_8_SCORE'>,
#         <Axes: xlabel='AVG_READING_8_SCORE', ylabel='AVG_MATH_8_SCORE'>],
#        [<Axes: xlabel='AVG_MATH_4_SCORE', ylabel='AVG_READING_4_SCORE'>,
#         <Axes: xlabel='AVG_MATH_8_SCORE', ylabel='AVG_READING_4_SCORE'>,
#         <Axes: xlabel='AVG_READING_4_SCORE', ylabel='AVG_READING_4_SCORE'>,
#         <Axes: xlabel='AVG_READING_8_SCORE', ylabel='AVG_READING_4_SCORE'>],
#        [<Axes: xlabel='AVG_MATH_4_SCORE', ylabel='AVG_READING_8_SCORE'>,
# ...

# %% [markdown]
# **<# The scatter matrix show that input variables are strongly correlated with response variable>**

# %% [markdown]
# <h2> Data Creation </h2>
#
# _Use this space to create train/test data_

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['AVG_MATH_4_SCORE', 'AVG_READING_4_SCORE', 'AVG_READING_8_SCORE']].dropna()
y = df.loc[X.index]['AVG_MATH_8_SCORE']
y.fillna(y.median(), inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)

# %% [markdown]
# <h2> Prediction </h2>

# %% [markdown]
# ML Models [Resource](https://medium.com/@vijaya.beeravalli/comparison-of-machine-learning-classification-models-for-credit-card-default-data-c3cf805c9a5a)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Choose some metrics to evaluate the performance of your model, some of them are mentioned in the tutorial.

# %%
np.mean(model.predict(X_test)-y_test)
# Out:
# 0.6212045711607203

# %% [markdown]
# We have copied over the graphs that visualize the model's performance on the training and testing set.
#
# Change `col_name` and modify the call to `plt.ylabel()` to isolate how a single predictor affects the model.

# %%
col_name = 'AVG_MATH_4_SCORE'

f = plt.figure(figsize=(12,6))
plt.scatter(X_train[col_name], y_train, color = "red")
plt.scatter(X_train[col_name], model.predict(X_train), color = "green")

plt.legend(['True Training','Predicted Training'])
plt.xlabel(col_name)
plt.ylabel('NAME OF THE PREDICTOR')
plt.title("Model Behavior On Training Set")
# Out:
# Text(0.5, 1.0, 'Model Behavior On Training Set')

# %%
col_name = "AVG_READING_4_SCORE"

f = plt.figure(figsize=(12,6))
plt.scatter(X_test[col_name], y_test, color = "blue")
plt.scatter(X_test[col_name], model.predict(X_test), color = "black")

plt.legend(['True testing','Predicted testing'])
plt.xlabel(col_name)
plt.ylabel('NAME OF THE PREDICTOR')
plt.title("Model Behavior on Testing Set")
# Out:
# Text(0.5, 1.0, 'Model Behavior on Testing Set')

# %%
col_name = "AVG_READING_8_SCORE"

f = plt.figure(figsize=(12,6))
plt.scatter(X_test[col_name], y_test, color = "purple")
plt.scatter(X_test[col_name], model.predict(X_test), color = "orange")

plt.legend(['True testing','Predicted testing'])
plt.xlabel(col_name)
plt.ylabel('NAME OF THE PREDICTOR')
plt.title("Model Behavior on Testing Set")
# Out:
# Text(0.5, 1.0, 'Model Behavior on Testing Set')

# %% [markdown]
# <h2> Summary </h2>

# %% [markdown]
# **<From the graph, I can see that my model works fairly well on the training set and also generalize nicely to the testing set. Overall, the model I developed is very similar to the one given in tutorial 1. All three input variables have strong correlations with the response variable, so using ordinary linear regression model effectively predict the response variable and avoid overfitting problem. After completing this checkpoint, I am planning continue to learn more regression models like ridge and Lasso regressions. I look forward to using them in future machine learning projects.\>**
